# %%
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import scipy.optimize as spopt 
import scipy.fftpack as spfft 
import scipy.ndimage as spimg 
import cvxpy as cvx
from PIL import Image
import matplotlib.image as mpimg
# %matplotlib inline

# %%
# SciPy는 2-D에서의 dct 또는 idct를 제공하지 않기 때문에 2-D 이산 코사인 변환 형태로 만든다

def dct2(x):
    return spfft.dct(spfft.dct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)

def idct2(x):
    return spfft.idct(spfft.idct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)

# %%
# 원본 이미지 읽기 및 사이즈 축소
img = Image.open('cbnu.jpg')
img_resize = img.resize((256, 256)) # 이미지를 256x256 형태로 변환
imgGray = img_resize.convert('L') # 그레이 스케일로 읽기

# %%
X = spimg.zoom(imgGray, 0.25) # 이미지를 64x64 형태로 변환
ny,nx = X.shape

# %%
plt.figure(figsize=(10, 8))
plt.subplot(131)
plt.imshow(img_resize)
plt.title("original image")

plt.subplot(132)
plt.imshow(imgGray)
plt.title("gray image")

plt.subplot(133)
imgplot = plt.imshow(X)
plt.title("downsized image")
# Out:
# Text(0.5, 1.0, 'downsized image')

# %%
# 작은 신호 샘플 추출
k = round(nx * ny * 0.5) # 50%를 샘플링한다
ri = np.random.choice(nx * ny, k, replace=False) # 임의의 인덱스를 샘플링한다
b = X.T.flat[ri]
b2 = np.expand_dims(b, axis=1)

# %%
# kron 을 사용하여 dct 행렬 연산자 생성한다(memory errors for large ny*nx)
A = np.kron(
    spfft.idct(np.identity(nx), norm='ortho', axis=0),
    spfft.idct(np.identity(ny), norm='ortho', axis=0)
    )
A = A[ri,:] # phi x kron

# %%
# do L1 optimization
vx = cvx.Variable(nx * ny)
objective = cvx.Minimize(cvx.norm(vx, 1))
constraints = [A*vx == b]
prob = cvx.Problem(objective, constraints)
result = prob.solve(verbose=True)
Xat2 = np.array(vx.value).squeeze()
# Out:
# ...
#                                      CVXPY
#                                     v1.1.11
# ...
# (CVXPY) May 27 04:16:43 AM: Your problem has 4096 variables, 1 constraints, and 0 parameters.
# (CVXPY) May 27 04:16:43 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 27 04:16:43 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 27 04:16:43 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 27 04:16:43 AM: Compiling problem (target solver=ECOS).
# (CVXPY) May 27 04:16:43 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) May 27 04:16:43 AM: Applying reduction Dcp2Cone
# ...

# %%
# 신호를 재구성한다
Xat = Xat2.reshape(nx, ny).T # stack columns
Xa = idct2(Xat)

# %%
# 결과를 확인한다
if not np.allclose(X.T.flat[ri], Xa.T.flat[ri]):
    print('Warning: values at sample indices don\'t match original.')

# %%
# 마스크 이미지 생성 (시각화 용)
mask = np.zeros(X.shape)
mask.T.flat[ri] = 255
Xm = 255 * np.ones(X.shape)
Xm.T.flat[ri] = X.T.flat[ri]

# %%
plt.figure(figsize=(10, 8))
plt.subplot(141)
imgplot = plt.imshow(X)

plt.subplot(142)
imgplot = plt.imshow(mask)

plt.subplot(143)
imgplot = plt.imshow(Xm)

plt.subplot(144)
imgplot = plt.imshow(Xa)

# %%
plt.figure(figsize=(10, 8))
plt.subplot(131)
plt.imshow(X[:,:]) # (y,x) = (50,50)
plt.title("downsized image")

plt.subplot(132)
plt.imshow(Xa[:,:]) # (y,x) = (50,50)
plt.title("result image")

plt.subplot(133)
plt.imshow(X[:,:]-Xa[:,:])
plt.title("[downsized image] - [result image]")
# Out:
# Text(0.5, 1.0, '[downsized image] - [result image]')

# %%
X[:,:]-Xa[:,:]
# Out:
# array([[ 7.10542736e-14,  9.94759830e-14, -4.49812412e+00, ...,
#         -4.54747351e-13,  2.55795385e-13, -5.15728662e+00],
#        [-1.36829865e+01,  1.67032517e+01,  1.42108547e-13, ...,
#         -3.41060513e-13, -1.06383429e+01,  4.29029634e+00],
#        [ 3.91292839e+01, -1.12566852e+00,  8.52651283e-14, ...,
#          3.00523200e+01,  2.14177956e+01,  2.84217094e-14],
#        ...,
#        [-6.53699317e-13, -3.52181706e+01,  5.96855898e-13, ...,
#          3.00845654e+01, -5.11590770e-13,  4.76063633e-13],
#        [-1.90238141e+01, -1.91476498e+01, -7.02150133e+00, ...,
#          3.37339823e+01,  1.63126906e+01,  3.43687099e+00],
#        [ 2.55795385e-13, -2.67128438e+01,  1.97662207e+01, ...,
#         -1.70530257e-13,  5.68434189e-14,  1.13686838e-13]])

# %% [markdown]
# #### MSE(Mean Squre Error)
# MSE는 평균 제곱 오차를 말하며 이미지 복원 분야뿐만 아니라 여러 이미지 관련 문제에서 이미지 간의 차이를 측정하기 위한 수단으로써 쓰이는 방법이다
# $$ MSE = \frac{1}{mn}\sum_{i=0}^{m-1}\sum_{j=0}^{n-1} [I(i,j)-K(i,j)]^2 $$
# 동일한 이미지 일수록 MSE 값은 0 이된다

# %%
# 방법 1
MSE = np.square(np.subtract(X,Xa)).mean()
MSE
# Out:
# 525.7108222055597

# %%
# 방법 2
from sklearn.metrics import mean_squared_error 
mean_squared_error(X, Xa)
# Out:
# 525.7108222055597

# %%
# 방법 3
def MSE(y_true, y_pred):
    return np.mean(np.square((y_true - y_pred)))
    
print(MSE(X, Xa))
# Out:
# 525.7108222055597

# %% [markdown]
# #### SSIM(Structural Similarity Index Map)
# 원본 이미지 A와 왜곡된 이미지 B 가 있다고 할 때 SSIM은 두 이미지의 휘도, 대비, 및 구조를 비교한다
# $$ SSIM(x,y) = \frac{(2\mu_x\mu_y+c_1)(2\sigma_{xy}+c_2)}{(\mu_x^2+\mu_y^2+c_1)(\sigma_x^2+\sigma_y^2+c_2)} $$
# 1에 가까울수록 유사도가 높다

# %%
import cv2
from skimage.metrics import structural_similarity as ssim

# %%
(score, diff) = ssim(X, Xa, full=True)
diff = (diff * 255).astype("uint8")

print(f"Similarity: {score:.5f}")

assert score
# Out:
# Similarity: 0.62192
# C:\Anaconda\envs\test\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
#   """Entry point for launching an IPython kernel.
