# %%
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import scipy.optimize as spopt 
import scipy.fftpack as spfft 
import scipy.ndimage as spimg 
import cvxpy as cvx
# %matplotlib inline

# %% [markdown]
# #### DCT(Discrete Cosine Transform) :
# $$ Y_k = \sum_{n=0}^{N-1} y_n \centerdot cos(2\pi\frac{k}{N}(\frac{2n+1}{4})) $$

# %% [markdown]
#  DFT와 유사하지만 기저함수로 복소 지수함수가 아닌 코사인 함수를 사용한다.
#  * DFT(Discrete Fourier Transform, 이산 푸리에 변환) :
#  길이가 N인 이산시간 시계열 데이터rk 있을 때 이 이산시간 시계열이 주기 N으로 계속 반복된다고 가정하여 푸리에 변환을 한 것이다.

# %%
# 인공적으로 신호를 만든다 (3개의 정현파의 합)
n = 5000
f1 = 500
f2 = 2600
f3 = 1498
t = np.linspace(0, 1/8, n) # 0에서 1/8까지 n개의 1차원 배열을 만든다

y = np.sin(f1 * np.pi * t) + np.sin(f2 * np.pi * t) + np.sin(f3 * np.pi * t)
# 정현파 3개를 만들어 합하는 식을 만든다

yt = spfft.dct(y, norm='ortho') 
k = np.linspace(0, 5000,  n)

# %%
plt.figure(figsize=(10,6))
plt.subplot(221)
plt.plot(t, y)
# 임의로 만든 신호

plt.subplot(222)
plt.plot(t, y)
plt.xlim([0, 0.025])
# 다른 범위의 신호

plt.subplot(223)
plt.plot(k, yt)
# 스펙트럼 영역의 신호 (신호의 주파수 성분)

plt.subplot(224)
plt.plot(k, yt)
plt.xlim([0, 500])
# 다른 범위의 스펙트럼 영역의 신호 (신호의 주파수 성분)
# Out:
# (0.0, 500.0)

# %%
m = 500 # 10% 를 샘플링
ri = np.random.choice(n, m, replace=False) # 무작위의 인덱스를 샘플링
ri.sort() # 리스트 객체 그 자체를 정렬만 할 뿐인 함수(꼭 필요한 것은 아니지만 플로팅에 편리함)
t2 = t[ri]
y2 = y[ri]

# %%
plt.figure(figsize=(10,4))
plt.subplot(131)
plt.plot(t, np.sin(f1 * np.pi * t) + np.sin(f2 * np.pi * t) + np.sin(f3 * np.pi * t))
plt.plot(t2, y2, 'o', c='r')
# 신호 중 10%를 샘플링

plt.subplot(132)
plt.plot(t[0:500], np.sin(f1 * np.pi * t[0:500]) + np.sin(f2 * np.pi * t[0:500]) + np.sin(f3 * np.pi * t[0:500]))
plt.plot(t2[0:48], y2[0:48],'o', c='r')

plt.subplot(133)
plt.plot(t2[0:48], y2[0:48], 'r')
# 10%의 데이터 만으로 신호를 복원

# %%
# idct 행렬 연산자 만들기
Psi_inv = spfft.idct(np.identity(n), norm='ortho', axis=0)
A = Psi_inv[ri]

# do L1 optimization
vx = cvx.Variable(n)
objective = cvx.Minimize(cvx.norm(vx, 1))
constraints = [A*vx == y2]
prob = cvx.Problem(objective, constraints)
result = prob.solve(verbose=True);
# Out:
# ...
#                                      CVXPY
#                                     v1.1.11
# ...
# (CVXPY) May 26 11:48:26 PM: Your problem has 5000 variables, 1 constraints, and 0 parameters.
# (CVXPY) May 26 11:48:26 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 26 11:48:26 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 26 11:48:26 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 26 11:48:26 PM: Compiling problem (target solver=ECOS).
# (CVXPY) May 26 11:48:26 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) May 26 11:48:26 PM: Applying reduction Dcp2Cone
# ...

# %%
# 신호 재구성
x = np.array(vx.value)
x = np.squeeze(x)
sig = spfft.idct(x, norm='ortho', axis=0)

plt.figure(figsize=(10,6))
plt.subplot(221)
plt.plot(k, yt)
plt.xlim([0, 500])
# 원래 스펙트럼 영역의 신호

plt.subplot(222)
plt.plot(k, x,'r')
plt.xlim([0, 500])
# CS 후의 스펙트럼 영역의 신호

plt.subplot(223)
plt.plot(t, y)
plt.xlim([0, 0.012])
# 임의로 만든 신호

plt.subplot(224)
plt.plot(t, sig,'r')
plt.xlim([0, 0.012])
# CS 후의 임의로 만든 신호
# Out:
# (0.0, 0.012)

# %%
plt.figure(figsize=(10,6))
plt.subplot(221)
plt.plot(t, y)
plt.plot(t, sig,'r')
plt.xlim([0, 0.012])

plt.subplot(222)
plt.plot(t, y)
plt.plot(t, sig,'r')
plt.xlim([0.012, 0.024])

plt.subplot(223)
plt.plot(t, y - sig)
plt.xlim([0, 0.012])

plt.subplot(224)
plt.plot(t, y - sig)
plt.xlim([0.012, 0.024])
# Out:
# (0.012, 0.024)

# %%
plt.plot(t, y - sig)

# %%
print(y)
print(sig)
# Out:
# [0.         0.35949974 0.70888327 ... 0.87141269 0.5828572  0.29289322]
# [0.35075137 0.35949974 0.33727168 ... 1.04348704 1.01904488 0.76159914]

# %%
print(y+3)
print(sig+3)
# Out:
# [3.         3.35949974 3.70888327 ... 3.87141269 3.5828572  3.29289322]
# [3.35075137 3.35949974 3.33727168 ... 4.04348704 4.01904488 3.76159914]

# %%
AVG = np.mean(((y-sig)) / (y+3) * 100)
print (AVG)
# Out:
# -2.427041047208563

# %%
from difflib import SequenceMatcher
SequenceMatcher(None, y+3, sig+3).ratio()
# Out:
# 0.0036

# %%
match_rate = f'{SequenceMatcher(None, y+3, sig+3).ratio()*100:.1f}%'
match_rate
# Out:
# '0.4%'
